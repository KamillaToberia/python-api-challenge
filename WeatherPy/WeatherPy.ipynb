# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 583

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=metric'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chonchi
# Processing Record 2 of Set 1 | whitehorse
# Processing Record 3 of Set 1 | rio grande
# Processing Record 4 of Set 1 | waitangi
# Processing Record 5 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 6 of Set 1 | ustka
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | inekar
# City not found. Skipping...
# Processing Record 11 of Set 1 | isafjordur
# Processing Record 12 of Set 1 | iqaluit
# Processing Record 13 of Set 1 | malango
# Processing Record 14 of Set 1 | west island
# Processing Record 15 of Set 1 | mandera
# Processing Record 16 of Set 1 | enewetak
# Processing Record 17 of Set 1 | port douglas
# Processing Record 18 of Set 1 | invercargill
# Processing Record 19 of Set 1 | mantua
# Processing Record 20 of Set 1 | praia
# Processing Record 21 of Set 1 | puerto natales
# Processing Record 22 of Set 1 | wailua homesteads
# Processing Record 23 of Set 1 | georgetown
# Processing Record 24 of Set 1 | ouellah
# City not found. Skipping...
# Processing Record 25 of Set 1 | east falmouth
# Processing Record 26 of Set 1 | lihue
# Processing Record 27 of Set 1 | bati
# Processing Record 28 of Set 1 | stanley
# Processing Record 29 of Set 1 | hasaki
# Processing Record 30 of Set 1 | smithers
# Processing Record 31 of Set 1 | olonkinbyen
# Processing Record 32 of Set 1 | moranbah
# Processing Record 33 of Set 1 | alofi
# Processing Record 34 of Set 1 | newman
# Processing Record 35 of Set 1 | port macquarie
# Processing Record 36 of Set 1 | longyearbyen
# Processing Record 37 of Set 1 | warman
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | adamstown
# Processing Record 40 of Set 1 | ndele
# Processing Record 41 of Set 1 | bethel
# Processing Record 42 of Set 1 | sao joao da barra
# Processing Record 43 of Set 1 | thompson
# Processing Record 44 of Set 1 | mabaruma
# Processing Record 45 of Set 1 | siwa oasis
# Processing Record 46 of Set 1 | fale old settlement
# Processing Record 47 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 48 of Set 1 | bouna
# Processing Record 49 of Set 1 | san bartolo
# Processing Record 50 of Set 1 | qaqortoq
# Processing Record 0 of Set 2 | yellowknife
# Processing Record 1 of Set 2 | grytviken
# Processing Record 2 of Set 2 | melilla
# Processing Record 3 of Set 2 | moab
# Processing Record 4 of Set 2 | jayapura
# Processing Record 5 of Set 2 | yuzhno-kurilsk
# Processing Record 6 of Set 2 | fort st. john
# Processing Record 7 of Set 2 | blackmans bay
# Processing Record 8 of Set 2 | saint-philippe
# Processing Record 9 of Set 2 | hotan
# Processing Record 10 of Set 2 | sandnessjoen
# Processing Record 11 of Set 2 | costa calma
# City not found. Skipping...
# Processing Record 12 of Set 2 | waveland
# Processing Record 13 of Set 2 | inhambane
# Processing Record 14 of Set 2 | mont-dore
# Processing Record 15 of Set 2 | lianzhou
# Processing Record 16 of Set 2 | constantia
# Processing Record 17 of Set 2 | kill devil hills
# Processing Record 18 of Set 2 | skiathos
# Processing Record 19 of Set 2 | tolanaro
# Processing Record 20 of Set 2 | west fargo
# Processing Record 21 of Set 2 | tomakomai
# Processing Record 22 of Set 2 | pacific grove
# Processing Record 23 of Set 2 | namibe
# Processing Record 24 of Set 2 | wajir
# Processing Record 25 of Set 2 | barcelos
# Processing Record 26 of Set 2 | san jacinto
# Processing Record 27 of Set 2 | g'ijduvon shahri
# City not found. Skipping...
# Processing Record 28 of Set 2 | gerash
# Processing Record 29 of Set 2 | edinburgh of the seven seas
# Processing Record 30 of Set 2 | albany
# Processing Record 31 of Set 2 | ushuaia
# Processing Record 32 of Set 2 | klyuchi
# Processing Record 33 of Set 2 | tsarevo
# Processing Record 34 of Set 2 | anadyr
# Processing Record 35 of Set 2 | college
# Processing Record 36 of Set 2 | turkmenbasy
# Processing Record 37 of Set 2 | ixtapa
# Processing Record 38 of Set 2 | eyl
# Processing Record 39 of Set 2 | miechow
# Processing Record 40 of Set 2 | nuuk
# Processing Record 41 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 42 of Set 2 | la passe
# Processing Record 43 of Set 2 | talnakh
# Processing Record 44 of Set 2 | carnarvon
# Processing Record 45 of Set 2 | akrehamn
# Processing Record 46 of Set 2 | manavalakurichi
# Processing Record 47 of Set 2 | axim
# Processing Record 48 of Set 2 | nova vodolaha
# Processing Record 49 of Set 2 | ourilandia do norte
# City not found. Skipping...
# Processing Record 0 of Set 3 | sanctuary point
# Processing Record 1 of Set 3 | port lavaca
# Processing Record 2 of Set 3 | hamilton
# Processing Record 3 of Set 3 | zouerate
# Processing Record 4 of Set 3 | chilliwack
# Processing Record 5 of Set 3 | opuwo
# Processing Record 6 of Set 3 | aasiaat
# Processing Record 7 of Set 3 | oudtshoorn
# Processing Record 8 of Set 3 | kapa'a
# Processing Record 9 of Set 3 | mount gambier
# Processing Record 10 of Set 3 | mount isa
# Processing Record 11 of Set 3 | ribeira grande
# Processing Record 12 of Set 3 | papatowai
# Processing Record 13 of Set 3 | saipan
# Processing Record 14 of Set 3 | zhangye
# Processing Record 15 of Set 3 | hilo
# Processing Record 16 of Set 3 | benguela
# Processing Record 17 of Set 3 | poronaysk
# Processing Record 18 of Set 3 | as sulayyil
# Processing Record 19 of Set 3 | balaipungut
# Processing Record 20 of Set 3 | nar'yan-mar
# Processing Record 21 of Set 3 | ma'rib
# Processing Record 22 of Set 3 | dudinka
# Processing Record 23 of Set 3 | velizh
# Processing Record 24 of Set 3 | margaret river
# Processing Record 25 of Set 3 | miles city
# Processing Record 26 of Set 3 | kone
# Processing Record 27 of Set 3 | peace river
# Processing Record 28 of Set 3 | fisterra
# Processing Record 29 of Set 3 | hawaiian paradise park
# Processing Record 30 of Set 3 | pachino
# Processing Record 31 of Set 3 | vorkuta
# Processing Record 32 of Set 3 | tralee
# Processing Record 33 of Set 3 | port mathurin
# Processing Record 34 of Set 3 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 35 of Set 3 | kingaroy
# Processing Record 36 of Set 3 | vadso
# Processing Record 37 of Set 3 | badger
# Processing Record 38 of Set 3 | springbok
# Processing Record 39 of Set 3 | kataba
# Processing Record 40 of Set 3 | albacete
# Processing Record 41 of Set 3 | tangalle
# Processing Record 42 of Set 3 | kurumkan
# Processing Record 43 of Set 3 | yaren
# Processing Record 44 of Set 3 | santa elena de uairen
# Processing Record 45 of Set 3 | sitka
# Processing Record 46 of Set 3 | castillos
# Processing Record 47 of Set 3 | bucak
# Processing Record 48 of Set 3 | murun-kuren
# Processing Record 49 of Set 3 | st. john's
# Processing Record 0 of Set 4 | colonia
# Processing Record 1 of Set 4 | udachny
# Processing Record 2 of Set 4 | suomussalmi
# Processing Record 3 of Set 4 | mount pearl
# Processing Record 4 of Set 4 | tiksi
# Processing Record 5 of Set 4 | kodiak
# Processing Record 6 of Set 4 | tvoroyri
# Processing Record 7 of Set 4 | geidam
# Processing Record 8 of Set 4 | bilibino
# Processing Record 9 of Set 4 | hermanus
# Processing Record 10 of Set 4 | jamestown
# Processing Record 11 of Set 4 | konarka
# Processing Record 12 of Set 4 | punta arenas
# Processing Record 13 of Set 4 | bemidji
# Processing Record 14 of Set 4 | yemva
# Processing Record 15 of Set 4 | huarmey
# Processing Record 16 of Set 4 | yangambi
# Processing Record 17 of Set 4 | merizo village
# Processing Record 18 of Set 4 | caleta de carquin
# Processing Record 19 of Set 4 | tadine
# Processing Record 20 of Set 4 | vernon
# Processing Record 21 of Set 4 | bahia honda
# Processing Record 22 of Set 4 | champerico
# Processing Record 23 of Set 4 | hartha
# Processing Record 24 of Set 4 | ilulissat
# Processing Record 25 of Set 4 | atafu village
# Processing Record 26 of Set 4 | antsiranana
# Processing Record 27 of Set 4 | queenstown
# Processing Record 28 of Set 4 | macau
# Processing Record 29 of Set 4 | ponce
# Processing Record 30 of Set 4 | kapuskasing
# Processing Record 31 of Set 4 | moyale
# Processing Record 32 of Set 4 | manicore
# Processing Record 33 of Set 4 | pangody
# Processing Record 34 of Set 4 | videira
# Processing Record 35 of Set 4 | ciudad lazaro cardenas
# Processing Record 36 of Set 4 | nikolayevsk-on-amure
# Processing Record 37 of Set 4 | aldinga beach
# Processing Record 38 of Set 4 | ust-nera
# Processing Record 39 of Set 4 | lakheri
# Processing Record 40 of Set 4 | east london
# Processing Record 41 of Set 4 | vorgashor
# Processing Record 42 of Set 4 | lethem
# Processing Record 43 of Set 4 | nadi
# Processing Record 44 of Set 4 | arteche
# Processing Record 45 of Set 4 | port elizabeth
# Processing Record 46 of Set 4 | yugo-kamskiy
# Processing Record 47 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 48 of Set 4 | onega
# Processing Record 49 of Set 4 | natal
# Processing Record 0 of Set 5 | launceston
# Processing Record 1 of Set 5 | hammerfest
# Processing Record 2 of Set 5 | kavaratti
# Processing Record 3 of Set 5 | san matias
# Processing Record 4 of Set 5 | alice springs
# Processing Record 5 of Set 5 | port kembla
# Processing Record 6 of Set 5 | pitea
# Processing Record 7 of Set 5 | fort bragg
# Processing Record 8 of Set 5 | susuman
# Processing Record 9 of Set 5 | shalkar
# Processing Record 10 of Set 5 | new norfolk
# Processing Record 11 of Set 5 | tippi
# Processing Record 12 of Set 5 | suizhou
# Processing Record 13 of Set 5 | beloyarskiy
# Processing Record 14 of Set 5 | port lincoln
# Processing Record 15 of Set 5 | san blas
# Processing Record 16 of Set 5 | lebu
# Processing Record 17 of Set 5 | kailua-kona
# Processing Record 18 of Set 5 | westport
# Processing Record 19 of Set 5 | ko lanta
# Processing Record 20 of Set 5 | bredasdorp
# Processing Record 21 of Set 5 | bolkhov
# Processing Record 22 of Set 5 | waingapu
# Processing Record 23 of Set 5 | bac lieu
# Processing Record 24 of Set 5 | howrah
# Processing Record 25 of Set 5 | thunder bay
# Processing Record 26 of Set 5 | al majaridah
# Processing Record 27 of Set 5 | pandan
# Processing Record 28 of Set 5 | tazacorte
# Processing Record 29 of Set 5 | firozpur jhirka
# Processing Record 30 of Set 5 | slavonski brod
# Processing Record 31 of Set 5 | jaffna
# Processing Record 32 of Set 5 | puerto aysen
# Processing Record 33 of Set 5 | keflavik
# Processing Record 34 of Set 5 | almirante
# Processing Record 35 of Set 5 | khandyga
# Processing Record 36 of Set 5 | kholmsk
# Processing Record 37 of Set 5 | kamianka
# Processing Record 38 of Set 5 | happy valley-goose bay
# Processing Record 39 of Set 5 | humahuaca
# Processing Record 40 of Set 5 | northam
# Processing Record 41 of Set 5 | berrahal
# Processing Record 42 of Set 5 | tura
# Processing Record 43 of Set 5 | devinuwara
# City not found. Skipping...
# Processing Record 44 of Set 5 | praia da vitoria
# Processing Record 45 of Set 5 | altamira
# Processing Record 46 of Set 5 | acapulco de juarez
# Processing Record 47 of Set 5 | kwolla
# Processing Record 48 of Set 5 | utrik
# Processing Record 49 of Set 5 | monteagudo
# Processing Record 0 of Set 6 | kasongo-lunda
# Processing Record 1 of Set 6 | san juan
# Processing Record 2 of Set 6 | kingston
# Processing Record 3 of Set 6 | tazovsky
# Processing Record 4 of Set 6 | shortandy
# Processing Record 5 of Set 6 | fort drum
# Processing Record 6 of Set 6 | maceio
# Processing Record 7 of Set 6 | aykhal
# Processing Record 8 of Set 6 | moyynkum
# Processing Record 9 of Set 6 | muisne
# Processing Record 10 of Set 6 | ventspils
# Processing Record 11 of Set 6 | baruun-urt
# Processing Record 12 of Set 6 | usogorsk
# Processing Record 13 of Set 6 | holualoa
# Processing Record 14 of Set 6 | puerto deseado
# Processing Record 15 of Set 6 | roberval
# Processing Record 16 of Set 6 | koh kong
# Processing Record 17 of Set 6 | tevriz
# Processing Record 18 of Set 6 | oranjemund
# Processing Record 19 of Set 6 | alaghsas
# Processing Record 20 of Set 6 | luderitz
# Processing Record 21 of Set 6 | jijiga
# Processing Record 22 of Set 6 | ancud
# Processing Record 23 of Set 6 | crane
# Processing Record 24 of Set 6 | amga
# Processing Record 25 of Set 6 | karratha
# Processing Record 26 of Set 6 | berdigestyakh
# Processing Record 27 of Set 6 | maumere
# Processing Record 28 of Set 6 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 29 of Set 6 | ceeldheer
# Processing Record 30 of Set 6 | brookings
# Processing Record 31 of Set 6 | ispir
# Processing Record 32 of Set 6 | labuan
# Processing Record 33 of Set 6 | guaruja
# Processing Record 34 of Set 6 | hailar
# Processing Record 35 of Set 6 | olovyannaya
# Processing Record 36 of Set 6 | vila franca do campo
# Processing Record 37 of Set 6 | bubaque
# Processing Record 38 of Set 6 | pingliang
# Processing Record 39 of Set 6 | kaa-khem
# Processing Record 40 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 41 of Set 6 | baharly
# Processing Record 42 of Set 6 | kayangel
# Processing Record 43 of Set 6 | yarmouth
# Processing Record 44 of Set 6 | kirakira
# Processing Record 45 of Set 6 | kenora
# Processing Record 46 of Set 6 | kenai
# Processing Record 47 of Set 6 | iskateley
# Processing Record 48 of Set 6 | la ronge
# Processing Record 49 of Set 6 | lata
# Processing Record 0 of Set 7 | berezovyy
# Processing Record 1 of Set 7 | kulia village
# City not found. Skipping...
# Processing Record 2 of Set 7 | bloomfield
# Processing Record 3 of Set 7 | ulladulla
# Processing Record 4 of Set 7 | ozimek
# Processing Record 5 of Set 7 | portland
# Processing Record 6 of Set 7 | quellon
# Processing Record 7 of Set 7 | sofifi
# City not found. Skipping...
# Processing Record 8 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record 9 of Set 7 | kolosovka
# Processing Record 10 of Set 7 | nova sintra
# Processing Record 11 of Set 7 | taoudenni
# Processing Record 12 of Set 7 | bonthe
# Processing Record 13 of Set 7 | kataragama
# City not found. Skipping...
# Processing Record 14 of Set 7 | sala
# Processing Record 15 of Set 7 | turpan
# Processing Record 16 of Set 7 | marsh harbour
# Processing Record 17 of Set 7 | inari
# Processing Record 18 of Set 7 | mbanza kongo
# Processing Record 19 of Set 7 | san antonio de pale
# Processing Record 20 of Set 7 | embarcacion
# Processing Record 21 of Set 7 | general mosconi
# Processing Record 22 of Set 7 | nemuro
# Processing Record 23 of Set 7 | guercif
# Processing Record 24 of Set 7 | juan griego
# Processing Record 25 of Set 7 | uturoa
# Processing Record 26 of Set 7 | saynshand
# Processing Record 27 of Set 7 | afaahiti
# Processing Record 28 of Set 7 | raduzhny
# Processing Record 29 of Set 7 | saudarkrokur
# Processing Record 30 of Set 7 | betare oya
# Processing Record 31 of Set 7 | balabac
# Processing Record 32 of Set 7 | fort mcmurray
# Processing Record 33 of Set 7 | tranovaho
# City not found. Skipping...
# Processing Record 34 of Set 7 | kidal
# Processing Record 35 of Set 7 | belyy yar
# Processing Record 36 of Set 7 | camapua
# Processing Record 37 of Set 7 | banda aceh
# Processing Record 38 of Set 7 | minas de marcona
# Processing Record 39 of Set 7 | acarau
# Processing Record 40 of Set 7 | ulysses
# Processing Record 41 of Set 7 | aral
# Processing Record 42 of Set 7 | mazamari
# Processing Record 43 of Set 7 | ballina
# Processing Record 44 of Set 7 | rawson
# Processing Record 45 of Set 7 | kerikeri
# Processing Record 46 of Set 7 | codrington
# Processing Record 47 of Set 7 | guisa
# Processing Record 48 of Set 7 | rongelap
# Processing Record 49 of Set 7 | hami
# Processing Record 0 of Set 8 | neusiedl am see
# Processing Record 1 of Set 8 | bekalta
# Processing Record 2 of Set 8 | prado
# Processing Record 3 of Set 8 | madalena
# Processing Record 4 of Set 8 | nguekhokh
# Processing Record 5 of Set 8 | soanierana ivongo
# Processing Record 6 of Set 8 | vodnyy
# Processing Record 7 of Set 8 | nicoya
# Processing Record 8 of Set 8 | haiku-pauwela
# Processing Record 9 of Set 8 | achacachi
# Processing Record 10 of Set 8 | kigoma
# Processing Record 11 of Set 8 | uliastay
# Processing Record 12 of Set 8 | sinop
# Processing Record 13 of Set 8 | nelson bay
# Processing Record 14 of Set 8 | talcahuano
# Processing Record 15 of Set 8 | bikenibeu village
# Processing Record 16 of Set 8 | mayya
# Processing Record 17 of Set 8 | margate
# Processing Record 18 of Set 8 | tinajo
# Processing Record 19 of Set 8 | vila velha
# Processing Record 20 of Set 8 | tynda
# Processing Record 21 of Set 8 | ta`u
# Processing Record 22 of Set 8 | sisimiut
# Processing Record 23 of Set 8 | prunedale
# Processing Record 24 of Set 8 | charters towers
# Processing Record 25 of Set 8 | bull savanna
# Processing Record 26 of Set 8 | yangor
# City not found. Skipping...
# Processing Record 27 of Set 8 | pontianak
# Processing Record 28 of Set 8 | tabas
# Processing Record 29 of Set 8 | erdenet
# Processing Record 30 of Set 8 | saint-pierre
# Processing Record 31 of Set 8 | paracuru
# Processing Record 32 of Set 8 | kisangani
# Processing Record 33 of Set 8 | torres
# Processing Record 34 of Set 8 | mulayjah
# Processing Record 35 of Set 8 | kalach-na-donu
# Processing Record 36 of Set 8 | greymouth
# Processing Record 37 of Set 8 | tongouson
# Processing Record 38 of Set 8 | vila do maio
# Processing Record 39 of Set 8 | castlegar
# Processing Record 40 of Set 8 | la foa
# Processing Record 41 of Set 8 | daru
# Processing Record 42 of Set 8 | edson
# Processing Record 43 of Set 8 | rubio
# Processing Record 44 of Set 8 | sahavato
# City not found. Skipping...
# Processing Record 45 of Set 8 | rokytne
# Processing Record 46 of Set 8 | celestun
# Processing Record 47 of Set 8 | gubkinskiy
# Processing Record 48 of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 49 of Set 8 | tres coroas
# Processing Record 0 of Set 9 | bandiagara
# Processing Record 1 of Set 9 | souillac
# Processing Record 2 of Set 9 | nouadhibou
# Processing Record 3 of Set 9 | san luis de la loma
# Processing Record 4 of Set 9 | sault ste. marie
# Processing Record 5 of Set 9 | batang
# Processing Record 6 of Set 9 | mikuni
# Processing Record 7 of Set 9 | zheshart
# Processing Record 8 of Set 9 | yongbyon
# Processing Record 9 of Set 9 | birjand
# Processing Record 10 of Set 9 | lepsy
# Processing Record 11 of Set 9 | rio gallegos
# Processing Record 12 of Set 9 | san patricio
# Processing Record 13 of Set 9 | cidade velha
# Processing Record 14 of Set 9 | faya-largeau
# Processing Record 15 of Set 9 | juan l. lacaze
# Processing Record 16 of Set 9 | rio preto da eva
# Processing Record 17 of Set 9 | nagqu
# Processing Record 18 of Set 9 | callao
# Processing Record 19 of Set 9 | dubbo
# Processing Record 20 of Set 9 | markovo
# Processing Record 21 of Set 9 | yerofey pavlovich
# Processing Record 22 of Set 9 | qingnian
# Processing Record 23 of Set 9 | copala
# Processing Record 24 of Set 9 | sanming
# Processing Record 25 of Set 9 | kingscliff
# Processing Record 26 of Set 9 | palmer
# Processing Record 27 of Set 9 | mar del plata
# Processing Record 28 of Set 9 | manakara
# Processing Record 29 of Set 9 | floro
# Processing Record 30 of Set 9 | naze
# Processing Record 31 of Set 9 | da nang
# Processing Record 32 of Set 9 | sakaiminato
# Processing Record 33 of Set 9 | cooma
# Processing Record 34 of Set 9 | vrangel'
# Processing Record 35 of Set 9 | sao geraldo do araguaia
# Processing Record 36 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 37 of Set 9 | arraial do cabo
# Processing Record 38 of Set 9 | soustons
# Processing Record 39 of Set 9 | hayma'
# City not found. Skipping...
# Processing Record 40 of Set 9 | dolores
# Processing Record 41 of Set 9 | sinabang
# Processing Record 42 of Set 9 | mata-utu
# Processing Record 43 of Set 9 | altay
# Processing Record 44 of Set 9 | lerwick
# Processing Record 45 of Set 9 | verkhnevilyuysk
# Processing Record 46 of Set 9 | hegang
# Processing Record 47 of Set 9 | makinsk
# Processing Record 48 of Set 9 | tchibanga
# Processing Record 49 of Set 9 | 'ayn al 'arab
# Processing Record 0 of Set 10 | redland bay
# Processing Record 1 of Set 10 | woolgoolga
# Processing Record 2 of Set 10 | carloforte
# Processing Record 3 of Set 10 | chernyshevskiy
# Processing Record 4 of Set 10 | urangan
# Processing Record 5 of Set 10 | chipinge
# Processing Record 6 of Set 10 | meulaboh
# Processing Record 7 of Set 10 | dunedin
# Processing Record 8 of Set 10 | xinyuan
# Processing Record 9 of Set 10 | arinos
# Processing Record 10 of Set 10 | vilyuchinsk
# Processing Record 11 of Set 10 | chichiriviche
# Processing Record 12 of Set 10 | taro
# Processing Record 13 of Set 10 | qala i naw
# Processing Record 14 of Set 10 | prince rupert
# Processing Record 15 of Set 10 | bel ombre
# Processing Record 16 of Set 10 | es castell
# Processing Record 17 of Set 10 | inarajan village
# Processing Record 18 of Set 10 | freetown
# Processing Record 19 of Set 10 | corralillo
# Processing Record 20 of Set 10 | sao raimundo nonato
# Processing Record 21 of Set 10 | iloilo
# Processing Record 22 of Set 10 | chadron
# Processing Record 23 of Set 10 | kuala belait
# Processing Record 24 of Set 10 | bagar
# Processing Record 25 of Set 10 | pemangkat
# Processing Record 26 of Set 10 | huangnihe
# Processing Record 27 of Set 10 | bozeman
# Processing Record 28 of Set 10 | polyarnyy
# Processing Record 29 of Set 10 | flen
# Processing Record 30 of Set 10 | la junta
# Processing Record 31 of Set 10 | olhao
# Processing Record 32 of Set 10 | george town
# Processing Record 33 of Set 10 | nianzishan
# Processing Record 34 of Set 10 | mocimboa
# Processing Record 35 of Set 10 | montagu
# Processing Record 36 of Set 10 | walvis bay
# Processing Record 37 of Set 10 | bilecik
# Processing Record 38 of Set 10 | cabo san lucas
# Processing Record 39 of Set 10 | rauma
# Processing Record 40 of Set 10 | enterprise
# Processing Record 41 of Set 10 | lufkin
# Processing Record 42 of Set 10 | puerto baquerizo moreno
# Processing Record 43 of Set 10 | touros
# Processing Record 44 of Set 10 | kitimat
# Processing Record 45 of Set 10 | saldanha
# Processing Record 46 of Set 10 | taunsa
# Processing Record 47 of Set 10 | mosfellsbaer
# Processing Record 48 of Set 10 | torghay
# Processing Record 49 of Set 10 | muhammadabad
# Processing Record 0 of Set 11 | calvinia
# Processing Record 1 of Set 11 | miguel ahumada
# Processing Record 2 of Set 11 | vanino
# Processing Record 3 of Set 11 | eydhafushi
# Processing Record 4 of Set 11 | pechenizhyn
# Processing Record 5 of Set 11 | gilgit
# Processing Record 6 of Set 11 | jogeva
# Processing Record 7 of Set 11 | maracaibo
# Processing Record 8 of Set 11 | camayenne
# Processing Record 9 of Set 11 | paraty
# Processing Record 10 of Set 11 | la'ie
# Processing Record 11 of Set 11 | al wafrah
# Processing Record 12 of Set 11 | colares
# Processing Record 13 of Set 11 | assare
# Processing Record 14 of Set 11 | cheremushki
# Processing Record 15 of Set 11 | demopolis
# Processing Record 16 of Set 11 | cidreira
# Processing Record 17 of Set 11 | sawakin
# Processing Record 18 of Set 11 | rengasdengklok
# Processing Record 19 of Set 11 | mont-joli
# Processing Record 20 of Set 11 | xilin hot
# Processing Record 21 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 22 of Set 11 | quatre cocos
# Processing Record 23 of Set 11 | guanica
# Processing Record 24 of Set 11 | seogwipo
# City not found. Skipping...
# Processing Record 25 of Set 11 | shiyan
# Processing Record 26 of Set 11 | shepparton
# Processing Record 27 of Set 11 | weno
# Processing Record 28 of Set 11 | fortuna
# Processing Record 29 of Set 11 | suai
# City not found. Skipping...
# Processing Record 30 of Set 11 | mahbubabad
# Processing Record 31 of Set 11 | labasa
# Processing Record 32 of Set 11 | shetpe
# Processing Record 33 of Set 11 | broome
# Processing Record 34 of Set 11 | tindouf
# Processing Record 35 of Set 11 | hithadhoo
# Processing Record 36 of Set 11 | sabang
# Processing Record 37 of Set 11 | termoli
# Processing Record 38 of Set 11 | geraldton
# Processing Record 39 of Set 11 | pangoa
# Processing Record 40 of Set 11 | westwood
# Processing Record 41 of Set 11 | murzuq
# Processing Record 42 of Set 11 | belyayevka
# Processing Record 43 of Set 11 | idri
# Processing Record 44 of Set 11 | nuku'alofa
# Processing Record 45 of Set 11 | barda
# Processing Record 46 of Set 11 | salavan
# Processing Record 47 of Set 11 | mawu
# Processing Record 48 of Set 11 | gwadar
# Processing Record 49 of Set 11 | santa cruz
# Processing Record 0 of Set 12 | kassala
# Processing Record 1 of Set 12 | zykovo
# Processing Record 2 of Set 12 | darhan
# Processing Record 3 of Set 12 | funtua
# Processing Record 4 of Set 12 | bor
# Processing Record 5 of Set 12 | yichun
# Processing Record 6 of Set 12 | novyy urengoy
# Processing Record 7 of Set 12 | bargarh
# Processing Record 8 of Set 12 | lengshuitan
# Processing Record 9 of Set 12 | coahuayana de hidalgo
# Processing Record 10 of Set 12 | yardimli
# Processing Record 11 of Set 12 | kourou
# Processing Record 12 of Set 12 | russkiy kameshkir
# Processing Record 13 of Set 12 | el calafate
# Processing Record 14 of Set 12 | vallenar
# Processing Record 15 of Set 12 | tremp
# Processing Record 16 of Set 12 | punta del este
# Processing Record 17 of Set 12 | guiratinga
# Processing Record 18 of Set 12 | nogliki
# Processing Record 19 of Set 12 | mukah
# City not found. Skipping...
# Processing Record 20 of Set 12 | timbuktu
# Processing Record 21 of Set 12 | azul
# Processing Record 22 of Set 12 | nampula
# Processing Record 23 of Set 12 | pisco
# Processing Record 24 of Set 12 | hirara
# Processing Record 25 of Set 12 | yakeshi
# Processing Record 26 of Set 12 | rockport
# Processing Record 27 of Set 12 | sirte
# Processing Record 28 of Set 12 | santana
# Processing Record 29 of Set 12 | borogontsy
# Processing Record 30 of Set 12 | choyr
# Processing Record 31 of Set 12 | buala
# Processing Record 32 of Set 12 | abbeville
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()
# Out:
# City          557
# Lat           557
# Lng           557
# Max Temp      557
# Humidity      557
# Cloudiness    557
# Wind Speed    557
# Country       557
# Date          557
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         faya  18.3851   42.4509     22.06        35          21        2.60
# 1      farsund  58.0948    6.8047     13.30       100           0        7.65
# 2  new norfolk -42.7826  147.0587     11.72        58          12        1.34
# 3    jamestown  42.0970  -79.2353      5.77        77         100        9.77
# 4      lanzhou  36.0564  103.7922     14.53        48          59        1.20
#
#   Country        Date
# 0      SA  1666108228
# 1      NO  1666108228
# 2      AU  1666108230
# 3      US  1666107934
# 4      CN  1666108230

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           chonchi -42.6128  -73.8092     10.62        96         100
# 1        whitehorse  60.7161 -135.0538     -5.29        91          48
# 2        rio grande -32.0350  -52.0986     21.08        84          33
# 3          waitangi -43.9535 -176.5597     15.46        89         100
# 4             ustka  54.5805   16.8619      2.03        98         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.51      CL  1702343054
# 1              4.18      CA  1702343487
# 2              7.28      BR  1702343487
# 3              4.02      NZ  1702343488
# 4              2.14      PL  1702343489

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature °C")
date=city_data_df['Date'].min()
plt.title(f"City Latitude vs. Temperature ({date})")
plt.tight_layout()

# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind='scatter', x='Lat', y='Humidity', marker='o', grid=True,\
                  facecolors='b', edgecolors='k', title=f'City Latitude vs. Humidity ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.tight_layout()

# Save the figure
plt.savefig("Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind='scatter', x='Lat', y='Cloudiness', marker='o', grid=True,\
                  facecolors='b', edgecolors='k', title=f'City Latitude vs. Cloudiness ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.tight_layout()
# Save the figure
plt.savefig("Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind='scatter', x='Lat', y='Wind Speed', marker='o', grid=True,\
                  facecolors='b', edgecolors='k', title=f'City Latitude vs. Wind Speed ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.tight_layout()

# Save the figure
plt.savefig("Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lr_funcV2(x,y,name,vbl,hemi):
    (slope,intercept,rvalue,pvalue,stderror)=linregress(x,y)
    reg_values= x*slope + intercept
    plt.plot(x,reg_values,color='r')
    plt.title(f'Latitude vs. {vbl} - {hemi}')
    plt.xlabel('Latitude')
    plt.ylabel(vbl)
    line_eq = f'y = {(round(slope,2))}x + {(round(intercept,2))}'
    print(f'Linear equation: {line_eq}')
    plt.savefig(f"LinearRegresion_{name}.png")
    print(f'The r-value is: {rvalue}')

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>= 0,:]
# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        whitehorse  60.7161 -135.0538     -5.29        91          48
# 4             ustka  54.5805   16.8619      2.03        98         100
# 8        isafjordur  66.0755  -23.1240     -5.08        81          34
# 9           iqaluit  63.7506  -68.5145    -27.55        96          69
# 12          mandera   3.9366   41.8670     28.03        53         100
#
#          Wind Speed Country        Date
# City_ID
# 1              4.18      CA  1702343487
# 4              2.14      PL  1702343489
# 8              1.89      IS  1702343490
# 9              1.85      CA  1702343192
# 12             3.22      KE  1702343091

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<= 0,:]

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            chonchi -42.6128  -73.8092     10.62        96         100
# 2         rio grande -32.0350  -52.0986     21.08        84          33
# 3           waitangi -43.9535 -176.5597     15.46        89         100
# 5             avarua -21.2078 -159.7750     27.03        78          75
# 6        port alfred -33.5906   26.8910     17.32        96           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.51      CL  1702343054
# 2              7.28      BR  1702343487
# 3              4.02      NZ  1702343488
# 5             10.29      CK  1702343489
# 6              2.24      ZA  1702343093

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Latitude vs. Temperature in Northern Hemisphere")
x = northern_hemi_df['Lat']
y = northern_hemi_df['Max Temp']
name = 'NH_LatVsMaxTemp'
vbl = 'Maximum Temperature C°'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = -0.77x + 33.71
# The r-value is: -0.8251199279163806

# %%
# Linear regression on Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')
plt.grid()

x = southern_hemi_df['Lat']
y = southern_hemi_df['Max Temp']
name = 'SH_LatVsMaxTemp'
vbl = 'Maximum Temperature C°'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = 0.28x + 29.39
# The r-value is: 0.5931201026227569

# %% [markdown]
# **Discussion about the linear relationship:**
#
# In the Northern Hemisphere, it is a negative correlation, while in the Southern Hemisphere, it is a positive correlation. maximum Temperature increases as we approach the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Humidity'], marker='o', facecolors='b', edgecolors='k')

plt.grid()
x = northern_hemi_df['Lat']
y = northern_hemi_df['Humidity']
name = 'NH_LatVsHumidity'
vbl = 'Humidity (%)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = 0.37x + 63.13
# The r-value is: 0.3559145714257789

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Humidity'], marker='o', facecolors='b', edgecolors='k')

plt.grid()
x = southern_hemi_df['Lat']
y = southern_hemi_df['Humidity']
name = 'SH_LatVsHumidity'
vbl = 'Humidity (%)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = 0.25x + 77.69
# The r-value is: 0.17762122905349842

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The linear equation for each hemisphere shows a very slightly positive correlation, which implies that proximity to the equator has no bearing on humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'], marker='o', facecolors='b', edgecolors='k')
plt.grid()

x = northern_hemi_df['Lat']
y = northern_hemi_df['Cloudiness']
name = 'NH_LatVsCloudiness'
vbl = 'Cloudiness (%)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = 0.43x + 44.42
# The r-value is: 0.20236671325172575

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'], marker='o', facecolors='b', edgecolors='k')

plt.grid()
x = southern_hemi_df['Lat']
y = southern_hemi_df['Cloudiness']
name = 'SH_LatVsCloudiness'
vbl = 'Cloudiness (%)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = -0.0x + 59.23
# The r-value is: -0.0005769902329378689

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The linear equation for each hemisphere shows a positive correlation, which implies that proximity to the equator has no bearing on cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'], marker='o', facecolors='b', edgecolors='k')

plt.grid()
x = northern_hemi_df['Lat']
y = northern_hemi_df['Wind Speed']
name = 'NH_LatVsWindSpeed'
vbl = 'Wind Speed (m/s)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = 0.01x + 3.01
# The r-value is: 0.11526659465142872

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'], marker='o', facecolors='b', edgecolors='k')

plt.grid()
x = southern_hemi_df['Lat']
y = southern_hemi_df['Wind Speed']
name = 'SH_LatVsWindSpeed'
vbl = 'Wind Speed (m/s)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = -0.04x + 2.83
# The r-value is: -0.22362401091236023

# %% [markdown]
# **Discussion about the linear relationship:**
#
# In the Latitude vs Wind speed the both hemispheres and the scatter points show that the data is too spread for there to be any realiable correlation between latitude and wind speed.
